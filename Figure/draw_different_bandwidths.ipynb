# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import numpy as np

import brewer2mpl
# brewer2mpl.get_map args: set name set type number of colors
bmap = brewer2mpl.get_map('Pastel1', 'qualitative', 3)
new_colors = bmap.mpl_colors
# new_colors = ['seashell', 'honeydew', 'lightcyan']

fig_title = ['(a) CVSQ & CVSP', '(b) AAoV', '(c) ACoV', '(d) AT & AC', '(e) AR', '(f) ASC & ATC']

labels = ['RA', 'D4PG', 'MAD4PG', 'MAMO']

colors = ['lightcoral', 'orange', 'lightgreen', 'cornflowerblue', 'darkviolet', 'seashell', 'honeydew', 'lightcyan']
markers = ['*', 'd', 's', '^', '^']
font_size = 45
legend_size = 40
markersize = 30
plt.figure(figsize=(48, 30))            # 确定图像画布的大小
plt.rcParams['font.sans-serif'] = ['Nimbus Roman']  # 设置字体
x_label = 'Bandwidth (MHz)'
#################################################################### #################################################################
plt.subplot(2, 3, 1)                        # 将画布分为两列

plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Cumulative VCPS Quality and Profit', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[0], fontsize=font_size, y=-0.2)     # 图的title
x_vals = [1, 1.5, 2, 2.5, 3]


ra_cq = [221.2348231572297, 225.94558022032388, 230.9602806317781, 232.9272257258669, 236.74950285709573]
d3pg_cq = [260.02895220883204, 261.930003778295, 263.5256663049404, 266.0573089855218, 278.40111865004013]
madrl_cq = [249.99099663489645, 247.72985509787424, 251.36963368518687, 248.6813686952037, 247.95297290583227]
mamodrl_cq = [231.74749200821037, 233.383737572, 245.4123682830202, 248.65852678187443, 260.341118777284]

ra_cc = [181.65288298261714, 188.11846255616155, 198.431242902245, 200.60608958207712, 205.321813739242]
d3pg_cc = [261.9028844922433, 259.7012284316506, 254.44822437688902, 249.1069998408073, 244.46606367081648]
madrl_cc = [163.96073612848292, 189.9033042835146, 203.1538561578501, 199.5656318874922, 194.67424798177356]
mamodrl_cc = [253.1211751143199, 270.4093885167952, 281.14356385949003, 281.8261897622806, 289.1014313332302]

diff = 1
x = np.arange(1, 6, 1)

width = diff * 0.12
small_width = diff * 0.03
label_text_size = 35

plt.bar(x - width - 5 * small_width, ra_cc, width, label='CVSP', hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x - width - 5 * small_width, ra_cq, width, label='CVSQ', bottom=ra_cc, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] - width - 7.5 * small_width, ra_cc[i]+ra_cq[i]+0.03*600, labels[0], fontsize=label_text_size, rotation=90)

plt.bar(x - width + 1 * small_width, d3pg_cc, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x - width + 1 * small_width, d3pg_cq, width, bottom=d3pg_cc, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] - width + -1.5 *  small_width, d3pg_cc[i]+d3pg_cq[i]+0.03*600, labels[1], fontsize=label_text_size, rotation=90)

plt.bar(x + 3 * small_width, madrl_cc, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x + 3 * small_width, madrl_cq, width, bottom=madrl_cc, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] + 0.5 * small_width, madrl_cq[i]+madrl_cc[i]+0.03*600, labels[2], fontsize=label_text_size, rotation=90)

plt.bar(x + 9 * small_width, mamodrl_cc, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x + 9 * small_width, mamodrl_cq, width, bottom=mamodrl_cc, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] + 6.5 * small_width, mamodrl_cq[i]+mamodrl_cc[i]+0.03*600, labels[3], fontsize=label_text_size, rotation=90)

plt.grid()
ax = plt.gca()
new_x_index = ['1', '1.5', '2', '2.5', '3']
plt.xticks(x, new_x_index, fontsize=font_size)
# ax.xaxis.set_major_locator(MultipleLocator(0.5))
plt.ylim(0, 700)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 2) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Age of View', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[1], fontsize=font_size, y=-0.2)     # 图的title


ra_aq = [0.262550589475901, 0.24684806593225367, 0.230132397894073, 0.22357591424711043, 0.2108349904763475]
d3pg_aq = [0.13323682597055972, 0.12689998740568334, 0.12158111231686532, 0.11314230338159394, 0.07199627116653282]
madrl_aq = [0.1666966778836786, 0.1742338163404195, 0.1621012210493763, 0.1718574232282713, 0.1734900903138927]
mamodrl_aq = [0.2275083599726323, 0.22205420809155213, 0.1819587723899325, 0.17113824406041872, 0.1321962707423864]

plt.plot(x_vals, ra_aq, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, d3pg_aq, linestyle="-", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
plt.plot(x_vals, madrl_aq, linestyle="-", marker=markers[2], markersize=markersize, color=colors[3], label=labels[2], linewidth=5.0)
plt.plot(x_vals, mamodrl_aq, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

ra_ac = [0.39449039005794284, 0.3729384581461283, 0.3385625236591833, 0.33131303472640944, 0.3155939542025268]
d3pg_ac = [0.12699038502585586, 0.13432923856116472, 0.15183925207703652, 0.1696433338639756, 0.18511312109727832]
madrl_ac = [0.4534642129050568, 0.366988985721618, 0.3228204794738327, 0.3347812270416925, 0.3510858400607544]
mamodrl_ac = [0.15626274961893397, 0.098635371610683, 0.0628547871350328, 0.060579367459064636, 0.036328562222566]

plt.ylim(0, 0.3) 
plt.tick_params(labelsize=font_size)

ax2 = plt.twinx()
ax2.plot(x_vals, ra_ac, linestyle=":", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
ax2.plot(x_vals, d3pg_ac, linestyle=":", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
ax2.plot(x_vals, madrl_ac, linestyle=":", marker=markers[2], markersize=markersize, color=colors[3], label=labels[2], linewidth=5.0)
ax2.plot(x_vals, mamodrl_ac, linestyle=":", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)
# ax2.ylim(0, 0.5)  
ax2.set_ylabel('Average Cost of View', fontsize=font_size)
ax2.set_ylim([0, 0.5])
ax2.tick_params(labelsize=font_size) 

ax2.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(0.5))
                    # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
# 设置坐标轴上刻度的字体大小

plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()

#################################################################### #################################################################
plt.subplot(2, 3, 3) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Cost of View', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[2], fontsize=font_size, y=-0.2)     # 图的title

ra_ac = [0.39449039005794284, 0.3729384581461283, 0.3385625236591833, 0.33131303472640944, 0.3155939542025268]
d3pg_ac = [0.12699038502585586, 0.13432923856116472, 0.15183925207703652, 0.1696433338639756, 0.18511312109727832]
madrl_ac = [0.4534642129050568, 0.366988985721618, 0.3228204794738327, 0.3347812270416925, 0.3510858400607544]
mamodrl_ac = [0.15626274961893397, 0.098635371610683, 0.0628547871350328, 0.060579367459064636, 0.036328562222566]

plt.plot(x_vals, ra_ac, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, d3pg_ac, linestyle="-", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
plt.plot(x_vals, madrl_ac, linestyle="-", marker=markers[2], markersize=markersize, color=colors[3], label=labels[2], linewidth=5.0)
plt.plot(x_vals, mamodrl_ac, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(0.5))
plt.ylim(0, 0.5)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################

plt.subplot(2, 3, 4)
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Timeliness and Consistency', fontsize=font_size)         # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[3], fontsize=font_size, y=-0.2)     # 图的title

ra_avt = [0.23143469931451094, 0.2347721960682186, 0.19550648107412585, 0.21036154384574282, 0.20004013064914145]
d3pg_avt = [0.14892963845221785, 0.11436340078780091, 0.11538770771201082, 0.09440717252101814, 0.0393829255276881]
madrl_avt = [0.169579294039104, 0.157499545126598, 0.1561943366987121, 0.1548977202302712, 0.1601903890198381]
mamodrl_avt = [0.0915921603516931, 0.08110818143719596, 0.0664344863705233, 0.0593681439091098, 0.0383689491782293]

ra_avc = [0.3092244247179862, 0.2820712731239938, 0.26496187072830635, 0.24339746984916175, 0.22702728021715643]
d3pg_avc = [0.10969760724807257, 0.14570486733250695, 0.13087121922414702, 0.14124499967245768, 0.12091628962479987]
madrl_avc = [0.1623727536505406, 0.1993352231611517, 0.1709615475753727, 0.192296977725271, 0.1934396422549744]
mamodrl_avc = [0.4334732480730863, 0.4313826594040411, 0.3658447151111667, 0.31755103331343393, 0.2729372530886223]

diff = 1
x = np.arange(1, 6, 1)

width = diff * 0.12
small_width = diff * 0.03
label_text_size = 35

plt.bar(x - width - 5 * small_width, ra_avt, width, label='AT', hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x - width - 5 * small_width, ra_avc, width, label='AC', bottom=ra_avt, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] - width - 7.5 * small_width, ra_avt[i]+ra_avc[i]+0.03*0.5, labels[0], fontsize=label_text_size, rotation=90)

plt.bar(x - width + 1 * small_width, d3pg_avt, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x - width + 1 * small_width, d3pg_avc, width, bottom=d3pg_avt, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] - width + -1.5 *  small_width, d3pg_avt[i]+d3pg_avc[i]+0.03*0.5, labels[1], fontsize=label_text_size, rotation=90)

plt.bar(x + 3 * small_width, madrl_avt, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x + 3 * small_width, madrl_avc, width, bottom=madrl_avt, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] + 0.5 * small_width, madrl_avc[i]+madrl_avt[i]+0.03*0.5, labels[2], fontsize=label_text_size, rotation=90)

plt.bar(x + 9 * small_width, mamodrl_avt, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x + 9 * small_width, mamodrl_avc, width, bottom=mamodrl_avt, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] + 6.5 * small_width, mamodrl_avc[i]+mamodrl_avt[i]+0.03*0.5, labels[3], fontsize=label_text_size, rotation=90)

plt.grid()
ax = plt.gca()
new_x_index = ['1', '1.5', '2', '2.5', '3']
plt.xticks(x, new_x_index, fontsize=font_size)

plt.ylim(0, 0.7)                    # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 5)                 # 将画布分为两列
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Redundancy', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[4], fontsize=font_size, y=-0.2)     # 图的title

ra_avr = [0.20598277310924384, 0.21449479166666663, 0.21469583333333328, 0.2270966666666669, 0.2436595238095238]
d3pg_avr = [0.04278993055555551, 0.05287096774193536, 0.05837986111111107, 0.08277222222222218, 0.09918205128205117]
madrl_avr = [0.2529166666666669, 0.3089583333333333, 0.2564444444444446, 0.2901666666666667, 0.3226666666666665]
mamodrl_avr = [0.002506249999999996, 0.0, 0.0, 0.0, 0.0]

plt.plot(x_vals, ra_avr, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, d3pg_avr, linestyle="-", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
plt.plot(x_vals, madrl_avr, linestyle="-", marker=markers[2], markersize=markersize, color=colors[3], label=labels[2], linewidth=5.0)
plt.plot(x_vals, mamodrl_avr, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

plt.grid()
ax = plt.gca()

# plt.ylim(0, 0.4)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
ax.xaxis.set_major_locator(MultipleLocator(0.5))

# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 6)                       # 将画布分为两列
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Sensing and Transmission Cost', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[5], fontsize=font_size, y=-0.2)     # 图的title

ra_avr = [0.20598277310924384, 0.21449479166666663, 0.21469583333333328, 0.2270966666666669, 0.2436595238095238]
d3pg_avr = [0.04278993055555551, 0.05287096774193536, 0.05837986111111107, 0.08277222222222218, 0.09918205128205117]
madrl_avr = [0.2529166666666669, 0.3089583333333333, 0.2564444444444446, 0.2901666666666667, 0.3226666666666665]
mamodrl_avr = [0.002506249999999996, 0.0, 0.0, 0.0, 0.0]

ra_avsc = [0.4617757768348732, 0.4713016872111327, 0.4666399544866637, 0.4689667909429361, 0.4744919574502896]
d3pg_avsc = [0.18084045666039333, 0.22649595641707226, 0.23816952224093066, 0.3133883079828469, 0.32047019160432916]
madrl_avsc = [0.5389767679534665, 0.459587024911733, 0.4924105378391942, 0.5137933450534221, 0.6003814073794803]
mamodrl_avsc = [0.23333500095821605, 0.1780142146877779, 0.131038247391626, 0.1117683398578979, 0.0761844471482361]

ra_avtc = [0.421458811755362, 0.3474961248208547, 0.2725189588279612, 0.23748603396832585, 0.20714501138936048]
d3pg_avtc = [0.11524054062646849, 0.11223867739610509, 0.10092650002775551, 0.08289165611487173, 0.061129001036066465]
madrl_avtc = [0.468225430975842, 0.3034062727256456, 0.186418438623166, 0.1780763892174763, 0.1159998594390725]
mamodrl_avtc = [0.15606874808911894, 0.0685742143389296, 0.03968007878976352, 0.0260987204459562, 0.0146369584081787]


diff = 1
x = np.arange(1, 6, 1)

width = diff * 0.12
small_width = diff * 0.03
label_text_size = 35

plt.bar(x - width - 5 * small_width, ra_avr, width, label='AR', hatch="-", color=new_colors[2], edgecolor=None)
plt.bar(x - width - 5 * small_width, ra_avtc, width, label='ATC', bottom=ra_avr, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x - width - 5 * small_width, ra_avsc, width, label='ASC', bottom=[ra_avr[i]+ra_avtc[i] for i in range(len(ra_avr))], hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] - width - 7.5 * small_width, ra_avtc[i]+ra_avsc[i]+ra_avr[i]+0.03*1, labels[0], fontsize=label_text_size, rotation=90)

plt.bar(x - width + 1 * small_width, d3pg_avr, width, hatch="-", color=new_colors[2], edgecolor=None)
plt.bar(x - width + 1 * small_width, d3pg_avtc, width, bottom=d3pg_avr, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x - width + 1 * small_width, d3pg_avsc, width, bottom=[d3pg_avtc[i]+d3pg_avr[i] for i in range(len(ra_avr))], hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] - width + -1.5 *  small_width, d3pg_avtc[i]+d3pg_avsc[i]+d3pg_avr[i]+0.03*1, labels[1], fontsize=label_text_size, rotation=90)

plt.bar(x + 3 * small_width, madrl_avr, width, hatch="-", color=new_colors[2], edgecolor=None)
plt.bar(x + 3 * small_width, madrl_avtc, width, bottom=madrl_avr, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x + 3 * small_width, madrl_avsc, width, bottom=[madrl_avr[i]+madrl_avtc[i] for i in range(len(ra_avr))], hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] + 0.5 * small_width, madrl_avsc[i]+madrl_avtc[i]+madrl_avr[i]+0.03*1, labels[2], fontsize=label_text_size, rotation=90)

plt.bar(x + 9 * small_width, mamodrl_avr, width, hatch="-", color=new_colors[2], edgecolor=None)
plt.bar(x + 9 * small_width, mamodrl_avtc, width, bottom=mamodrl_avr, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x + 9 * small_width, mamodrl_avsc, width, bottom=[mamodrl_avtc[i]+mamodrl_avr[i] for i in range(len(ra_avr))], hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] + 6.5 * small_width, mamodrl_avsc[i]+mamodrl_avtc[i]+mamodrl_avr[i]+0.03*1, labels[3], fontsize=label_text_size, rotation=90)

# plt.grid()
ax = plt.gca()
new_x_index = ['1', '1.5', '2', '2.5', '3']
plt.xticks(x, new_x_index, fontsize=font_size)

plt.grid()
plt.ylim(0, 1.6)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# ax = plt.gca()
# ax.xaxis.set_major_locator(MultipleLocator(0.5))

# plt.savefig('different_bandwidth.png', dpi=50)
plt.subplots_adjust(wspace =0.2, hspace =0.25)#调整子图间距
plt.savefig("Fig-Different-Bandwidths.pdf", bbox_inches='tight')
plt.show()
