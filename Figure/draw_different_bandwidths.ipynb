# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import numpy as np

import brewer2mpl
# brewer2mpl.get_map args: set name set type number of colors
bmap = brewer2mpl.get_map('Pastel1', 'qualitative', 3)
new_colors = bmap.mpl_colors
# new_colors = ['seashell', 'honeydew', 'lightcyan']

fig_title = ['(a) CR', '(b) AAoV', '(c) AC', '(d) AVT&AVC', '(e) AVR', '(f) AVSC&AVTC']

labels = ['RA', 'D3PG', 'MADRL', 'MAMO']

colors = ['lightcoral', 'orange', 'lightgreen', 'cornflowerblue', 'darkviolet', 'seashell', 'honeydew', 'lightcyan']
markers = ['*', 'd', 's', '^', '^']
font_size = 45
legend_size = 40
markersize = 30
plt.figure(figsize=(48, 30))            # 确定图像画布的大小
plt.rcParams['font.sans-serif'] = ['Nimbus Roman']  # 设置字体
x_label = 'Bandwidth (MHz)'
#################################################################### #################################################################
plt.subplot(2, 3, 1)                        # 将画布分为两列

plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Cumulative Reward', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[0], fontsize=font_size, y=-0.2)     # 图的title
x_vals = [2, 2.5, 3, 3.5, 4]

ra_cq = [223.80005616464396, 230.49231247693857, 236.1594432768502, 238.3289811085082, 244.47733068948895]
d3pg_cq = [0, 0, 0, 0, 0]
madrl_cq = [0, 0, 0, 0, 0]
mamodrl_cq = [245.79970621398945, 253.01658190940233, 253.55061967685384, 265.54251022605644, 266.30550164537715]

ra_cc = [194.10277814874138, 201.66843894280413, 206.55159168453707, 207.3625241399546, 211.67877886576645]
d3pg_cc = [0, 0, 0, 0, 0]
madrl_cc = [0, 0, 0, 0, 0]
mamodrl_cc = [274.71129093322395, 285.3506323692348, 285.3631281721773, 224.05845704602564, 244.92313563990965]

plt.plot(x_vals, ra_cq, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, d3pg_cq, linestyle="-", marker=markers[1], markersize=markersize, color=colors[1], label=labels[1], linewidth=5.0)
plt.plot(x_vals, madrl_cq, linestyle="-", marker=markers[2], markersize=markersize, color=colors[2], label=labels[2], linewidth=5.0)
plt.plot(x_vals, mamodrl_cq, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

plt.plot(x_vals, ra_cc, linestyle="-.", marker=markers[0], markersize=markersize, color=colors[0], linewidth=5.0)
plt.plot(x_vals, d3pg_cc, linestyle="-.", marker=markers[1], markersize=markersize, color=colors[1], linewidth=5.0)
plt.plot(x_vals, madrl_cc, linestyle="-.", marker=markers[2], markersize=markersize, color=colors[2], linewidth=5.0)
plt.plot(x_vals, mamodrl_cc, linestyle="-.", marker=markers[4], markersize=markersize, color=colors[4], linewidth=5.0)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(0.5))
# plt.ylim(50, 250)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 2) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Age of View', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[1], fontsize=font_size, y=-0.2)     # 图的title

ra_aq = [0.25399981278452005, 0.231692291743538, 0.21280185574383262, 0.20557006297163943, 0.18507556436837008]
d3pg_aq = [0, 0, 0, 0, 0]
madrl_aq = [0, 0, 0, 0, 0]
mamodrl_aq = [0.1806676459533683, 0.15661139363532545, 0.15483126774382053, 0.1148582992464787, 0.1123149945154088]

plt.plot(x_vals, ra_aq, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, d3pg_aq, linestyle="-", marker=markers[1], markersize=markersize, color=colors[1], label=labels[1], linewidth=5.0)
plt.plot(x_vals, madrl_aq, linestyle="-", marker=markers[2], markersize=markersize, color=colors[2], label=labels[2], linewidth=5.0)
plt.plot(x_vals, mamodrl_aq, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(0.5))
# plt.ylim(5, 25)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()

#################################################################### #################################################################
plt.subplot(2, 3, 3) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Cost', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[2], fontsize=font_size, y=-0.2)     # 图的title

ra_ac = [0.3529907395041954, 0.32777187019065296, 0.31149469438487637, 0.3087915862001514, 0.2944040704474449]
d3pg_ac = [0, 0, 0, 0, 0]
madrl_ac = [0, 0, 0, 0, 0]
mamodrl_ac = [0.084295696889253, 0.048831225435883946, 0.04878957275940891, 0.2531384765132474, 0.1835895478669668]

plt.plot(x_vals, ra_ac, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, d3pg_ac, linestyle="-", marker=markers[1], markersize=markersize, color=colors[1], label=labels[1], linewidth=5.0)
plt.plot(x_vals, madrl_ac, linestyle="-", marker=markers[2], markersize=markersize, color=colors[2], label=labels[2], linewidth=5.0)
plt.plot(x_vals, mamodrl_ac, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(0.5))
# plt.ylim(0.3, 0.7)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################

plt.subplot(2, 3, 4)
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Timeliness and Consistency', fontsize=font_size)         # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[3], fontsize=font_size, y=-0.2)     # 图的title

ra_avt = [0.2412132028056541, 0.22137421338424734, 0.20239961185403282, 0.1925891347104278, 0.17579030592683637]
d3pg_avt = [0, 0, 0, 0, 0]
madrl_avt = [0, 0, 0, 0, 0]
mamodrl_avt = [0.1271245561879226, 0.059981202698978206, 0.05314253457817301, 0.1531152622987811, 0.1505093382964005]

ra_avc = [0.27317972775281896, 0.24716940928247416, 0.22840522157853252, 0.22504145536345682, 0.1637982122733898]
d3pg_avc = [0, 0, 0, 0, 0]
madrl_avc = [0, 0, 0, 0, 0]
mamodrl_avc = [0.2609822806015374, 0.3015566800398465, 0.307364367492292, 0.0574728546680253, 0.0550234788439212]

plt.plot(x_vals, ra_avt, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, d3pg_avt, linestyle="-", marker=markers[1], markersize=markersize, color=colors[1], label=labels[1], linewidth=5.0)
plt.plot(x_vals, madrl_avt, linestyle="-", marker=markers[2], markersize=markersize, color=colors[2], label=labels[2], linewidth=5.0)
plt.plot(x_vals, mamodrl_avt, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

plt.plot(x_vals, ra_avc, linestyle="-.", marker=markers[0], markersize=markersize, color=colors[0], linewidth=5.0)
plt.plot(x_vals, d3pg_avc, linestyle="-.", marker=markers[1], markersize=markersize, color=colors[1], linewidth=5.0)
plt.plot(x_vals, madrl_avc, linestyle="-.", marker=markers[2], markersize=markersize, color=colors[2],  linewidth=5.0)
plt.plot(x_vals, mamodrl_avc, linestyle="-.", marker=markers[4], markersize=markersize, color=colors[4],  linewidth=5.0)

plt.gca().yaxis.get_offset_text().set(size=font_size) 

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(0.5))
# plt.ylim(0.5e-6, 3e-6)                    # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 5)                 # 将画布分为两列
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Redundancy', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[4], fontsize=font_size, y=-0.2)     # 图的title

ra_avr = [0.24430952380952387, 0.24302380952380953, 0.23006666666666678, 0.22804444444444458, 0.22845555555555572]
d3pg_avr = [0, 0, 0, 0, 0]
madrl_avr = [0, 0, 0, 0, 0]
mamodrl_avr = [0.0, 0.0, 0.0003909897292250191, 0.107719298245614, 0.1014285714285716]

plt.plot(x_vals, ra_avr, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, d3pg_avr, linestyle="-", marker=markers[1], markersize=markersize, color=colors[1], label=labels[1], linewidth=5.0)
plt.plot(x_vals, madrl_avr, linestyle="-", marker=markers[2], markersize=markersize, color=colors[2], label=labels[2], linewidth=5.0)
plt.plot(x_vals, mamodrl_avr, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

plt.grid()
ax = plt.gca()

# plt.ylim(2, 4)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
ax.xaxis.set_major_locator(MultipleLocator(0.5))

# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 6)                       # 将画布分为两列
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Sensing and Transmission Cost', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[5], fontsize=font_size, y=-0.2)     # 图的title

ra_avsc = [0.46491546655170757, 0.4724059338744106, 0.4633685288701521, 0.4711254236651176, 0.46606605634813525]
d3pg_avsc = [0, 0, 0, 0, 0]
madrl_avsc = [0, 0, 0, 0, 0]
mamodrl_avsc = [0.1606473315526927, 0.0948876595486336, 0.09379204293274007, 0.5044090997079953, 0.3617399109069397]

ra_avtc = [0.2954066203040192, 0.22551183684031692, 0.2003348737587054, 0.18683131961303862, 0.15571634199269896]
d3pg_avtc = [0, 0, 0, 0, 0]
madrl_avtc = [0, 0, 0, 0, 0]
mamodrl_avtc = [0.0500919106704399, 0.02719040404107629, 0.027986394101169744, 0.0745774424523164, 0.0465196730461911]

plt.plot(x_vals, ra_avsc, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, d3pg_avsc, linestyle="-", marker=markers[1], markersize=markersize, color=colors[1], label=labels[1], linewidth=5.0)
plt.plot(x_vals, madrl_avsc, linestyle="-", marker=markers[2], markersize=markersize, color=colors[2], label=labels[2], linewidth=5.0)
plt.plot(x_vals, mamodrl_avsc, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

plt.plot(x_vals, ra_avtc, linestyle="-.", marker=markers[0], markersize=markersize, color=colors[0], linewidth=5.0)
plt.plot(x_vals, d3pg_avtc, linestyle="-.", marker=markers[1], markersize=markersize, color=colors[1], linewidth=5.0)
plt.plot(x_vals, madrl_avtc, linestyle="-.", marker=markers[2], markersize=markersize, color=colors[2], linewidth=5.0)
plt.plot(x_vals, mamodrl_avtc, linestyle="-.", marker=markers[4], markersize=markersize, color=colors[4], linewidth=5.0)


# plt.ylim(0.2, 0.5)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(0.5))
plt.grid()
# plt.savefig('different_bandwidth.png', dpi=50)
plt.subplots_adjust(wspace =0.2, hspace =0.25)#调整子图间距
plt.savefig("Fig-Different-Bandwidths.pdf", bbox_inches='tight')
plt.show()
