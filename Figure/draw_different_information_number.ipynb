# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import numpy as np

import brewer2mpl
# brewer2mpl.get_map args: set name set type number of colors
bmap = brewer2mpl.get_map('Pastel1', 'qualitative', 3)
new_colors = bmap.mpl_colors
# new_colors = ['seashell', 'honeydew', 'lightcyan']

fig_title = ['(a) CVSQ & CVSP', '(b) AAoV', '(c) ACoV', '(d) AT & AC', '(e) AR', '(f) ASC & ATC']

labels = ['RA', 'D4PG', 'MAD4PG', 'MAMO']

colors = ['lightcoral', 'orange', 'lightgreen', 'cornflowerblue', 'darkviolet', 'seashell', 'honeydew', 'lightcyan']
markers = ['*', 'd', 's', '^', '^']
font_size = 45
legend_size = 40
markersize = 30
plt.figure(figsize=(48, 30))            # 确定图像画布的大小
plt.rcParams['font.sans-serif'] = ['Nimbus Roman']  # 设置字体
x_label = 'Average Information Number'
#################################################################### #################################################################
plt.subplot(2, 3, 1)                        # 将画布分为两列

plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Cumulative VCPS Quality and Profit', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[0], fontsize=font_size, y=-0.2)     # 图的title
x_vals = [3, 4, 5, 6, 7]

ra_cq = [251.0162647830352, 240.14338112034784, 230.9602806317781, 220.6739113651123, 215.74575940895645]
d3pg_cq = [276.88995079577086, 265.45371101143144, 263.5256663049404, 263.1382699470516, 245.72528316985768]
madrl_cq = [260.56122621119493, 258.1863811130164, 251.36963368518687, 243.3508374922581, 235.77988501263317]
mamodrl_cq = [269.6689675914205, 245.3815662814252, 245.4123682830202, 243.92154772694028, 230.3513336042205]

ra_cc = [218.85009374034814, 205.39558450826928, 198.431242902245, 190.05779602010537, 187.51170496095983]
d3pg_cc = [264.67290471792387, 255.82666713090657, 254.44822437688902, 246.02787978671563, 241.803320339914]
madrl_cc = [209.0626372302204, 192.05148575994872, 203.1538561578501, 208.92166506048184, 195.98183319824787]
mamodrl_cc = [287.0084684647023, 285.0450940871846, 281.14356385949003, 274.4502452387901, 271.9268929233624]

# plt.plot(x_vals, ra_cq, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
# plt.plot(x_vals, d3pg_cq, linestyle="-", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
# plt.plot(x_vals, madrl_cq, linestyle="-", marker=markers[2], markersize=markersize, color=colors[3], label=labels[2], linewidth=5.0)
# plt.plot(x_vals, mamodrl_cq, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

# plt.plot(x_vals, ra_cc, linestyle="-.", marker=markers[0], markersize=markersize, color=colors[0], linewidth=5.0)
# plt.plot(x_vals, d3pg_cc, linestyle="-.", marker=markers[1], markersize=markersize, color=colors[2], linewidth=5.0)
# plt.plot(x_vals, madrl_cc, linestyle="-.", marker=markers[2], markersize=markersize, color=colors[3], linewidth=5.0)
# plt.plot(x_vals, mamodrl_cc, linestyle="-.", marker=markers[4], markersize=markersize, color=colors[4], linewidth=5.0)
diff = 1
x = np.arange(1, 6, 1)

width = diff * 0.12
small_width = diff * 0.03
label_text_size = 35

plt.bar(x - width - 5 * small_width, ra_cc, width, label='CVSP', hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x - width - 5 * small_width, ra_cq, width, label='CVSQ', bottom=ra_cc, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] - width - 7.5 * small_width, ra_cc[i]+ra_cq[i]+0.03*600, labels[0], fontsize=label_text_size, rotation=90)

plt.bar(x - width + 1 * small_width, d3pg_cc, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x - width + 1 * small_width, d3pg_cq, width, bottom=d3pg_cc, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] - width + -1.5 *  small_width, d3pg_cc[i]+d3pg_cq[i]+0.03*600, labels[1], fontsize=label_text_size, rotation=90)

plt.bar(x + 3 * small_width, madrl_cc, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x + 3 * small_width, madrl_cq, width, bottom=madrl_cc, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] + 0.5 * small_width, madrl_cq[i]+madrl_cc[i]+0.03*600, labels[2], fontsize=label_text_size, rotation=90)

plt.bar(x + 9 * small_width, mamodrl_cc, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x + 9 * small_width, mamodrl_cq, width, bottom=mamodrl_cc, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] + 6.5 * small_width, mamodrl_cq[i]+mamodrl_cc[i]+0.03*600, labels[3], fontsize=label_text_size, rotation=90)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
new_x_index = ['3', '4', '5', '6', '7']
plt.xticks(x, new_x_index, fontsize=font_size)
plt.ylim(0, 700)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 2) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Age of View', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[1], fontsize=font_size, y=-0.2)     # 图的title

ra_aq = [0.16327911738988238, 0.19952206293217362, 0.230132397894073, 0.2644202954496257, 0.2808474686368118]
d3pg_aq = [0.07703349734743065, 0.11515429662856182, 0.12158111231686532, 0.12287243350982817, 0.1809157227671411]
madrl_aq = [0.1314625792960169, 0.1393787296232782, 0.1621012210493763, 0.1888305416924733, 0.21406704995788980]
mamodrl_aq = [0.10110344136193176, 0.1820614457285821, 0.1819587723899325, 0.1869281742435324, 0.2321622213192649]

plt.plot(x_vals, ra_aq, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, d3pg_aq, linestyle="-", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
plt.plot(x_vals, madrl_aq, linestyle="-", marker=markers[2], markersize=markersize, color=colors[3], label=labels[2], linewidth=5.0)
plt.plot(x_vals, mamodrl_aq, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
plt.ylim(0, 0.3)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()

#################################################################### #################################################################
plt.subplot(2, 3, 3) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Cost of View', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[2], fontsize=font_size, y=-0.2)     # 图的title

ra_ac = [0.2704996875321728, 0.3153480516391025, 0.3385625236591833, 0.3664740132663153, 0.374960983463467]
d3pg_ac = [0.11775698427358716, 0.14724444289697813, 0.15183925207703652, 0.17990706737761453, 0.19398893220028676]
madrl_ac = [0.3031245425659318, 0.3598283808001709, 0.3228204794738327, 0.3035944497983938, 0.3467272226725075]
mamodrl_ac = [0.043305105117658886, 0.0498496863760512, 0.0628547871350328, 0.08516584920403299, 0.0935770235887919]

plt.plot(x_vals, ra_ac, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, d3pg_ac, linestyle="-", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
plt.plot(x_vals, madrl_ac, linestyle="-", marker=markers[2], markersize=markersize, color=colors[3], label=labels[2], linewidth=5.0)
plt.plot(x_vals, mamodrl_ac, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
plt.ylim(0, 0.4)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################

plt.subplot(2, 3, 4)
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Timeliness and Consistency', fontsize=font_size)         # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[3], fontsize=font_size, y=-0.2)     # 图的title

ra_avt = [0.16809052275719868, 0.18600753729890196, 0.19550648107412585, 0.24220778305550478, 0.3319689689345716]
d3pg_avt = [0.08499471182462116, 0.10762130410802927, 0.11538770771201082, 0.11995177866126083, 0.14637417478632556]
madrl_avt = [0.1413271030889603, 0.1560084027748108, 0.1561943366987121, 0.1688122476000917, 0.1610926368892769]
mamodrl_avt = [0.04361717227798608, 0.0869883001680027, 0.073529717891742, 0.06947492306278055, 0.1142062680219887]

ra_avc = [0.15606200933890796, 0.219793851382081, 0.26496187072830635, 0.29773906404080697, 0.204165218190173]
d3pg_avc = [0.0650916756316449, 0.1264537854093606, 0.13087121922414702, 0.12725341578267915, 0.23272804473836442]
madrl_avc = [0.1166657936066021, 0.1144342198959793, 0.1709615475753727, 0.2188579828310454, 0.293528669560809]
mamodrl_avc = [0.18733284498785008, 0.3246711640694515, 0.3658447151111667, 0.36310805101466015, 0.4090961512651792]

# plt.plot(x_vals, ra_avt, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
# plt.plot(x_vals, d3pg_avt, linestyle="-", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
# plt.plot(x_vals, madrl_avt, linestyle="-", marker=markers[2], markersize=markersize, color=colors[3], label=labels[2], linewidth=5.0)
# plt.plot(x_vals, mamodrl_avt, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

# plt.plot(x_vals, ra_avc, linestyle="-.", marker=markers[0], markersize=markersize, color=colors[0], linewidth=5.0)
# plt.plot(x_vals, d3pg_avc, linestyle="-.", marker=markers[1], markersize=markersize, color=colors[2], linewidth=5.0)
# plt.plot(x_vals, madrl_avc, linestyle="-.", marker=markers[2], markersize=markersize, color=colors[3],  linewidth=5.0)
# plt.plot(x_vals, mamodrl_avc, linestyle="-.", marker=markers[4], markersize=markersize, color=colors[4],  linewidth=5.0)

diff = 1
x = np.arange(1, 6, 1)

width = diff * 0.12
small_width = diff * 0.03
label_text_size = 35

plt.bar(x - width - 5 * small_width, ra_avt, width, label='AT', hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x - width - 5 * small_width, ra_avc, width, label='AC', bottom=ra_avt, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] - width - 7.5 * small_width, ra_avt[i]+ra_avc[i]+0.03*0.5, labels[0], fontsize=label_text_size, rotation=90)

plt.bar(x - width + 1 * small_width, d3pg_avt, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x - width + 1 * small_width, d3pg_avc, width, bottom=d3pg_avt, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] - width + -1.5 *  small_width, d3pg_avt[i]+d3pg_avc[i]+0.03*0.5, labels[1], fontsize=label_text_size, rotation=90)

plt.bar(x + 3 * small_width, madrl_avt, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x + 3 * small_width, madrl_avc, width, bottom=madrl_avt, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] + 0.5 * small_width, madrl_avc[i]+madrl_avt[i]+0.03*0.5, labels[2], fontsize=label_text_size, rotation=90)

plt.bar(x + 9 * small_width, mamodrl_avt, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x + 9 * small_width, mamodrl_avc, width, bottom=mamodrl_avt, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] + 6.5 * small_width, mamodrl_avc[i]+mamodrl_avt[i]+0.03*0.5, labels[3], fontsize=label_text_size, rotation=90)


plt.gca().yaxis.get_offset_text().set(size=font_size) 

plt.grid()
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))
new_x_index = ['3', '4', '5', '6', '7']
plt.xticks(x, new_x_index, fontsize=font_size)
plt.ylim(0, 0.65)                    # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 5)                 # 将画布分为两列
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Redundancy', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[4], fontsize=font_size, y=-0.2)     # 图的title

ra_avr = [0.18831111111111132, 0.22509345238095238, 0.21449479166666663, 0.23268888888888903, 0.2298809523809525]
d3pg_avr = [0.056456249999999965, 0.07513333333333333, 0.05287096774193536, 0.07603888888888885, 0.054988461538461424]
madrl_avr = [0.36875, 0.3308974358974363, 0.2564444444444446, 0.2121212121212122, 0.2365384615384617]
mamodrl_avr = [0.018334789644012927, 0.0, 0.0, 9.047619047619e-05, 0.0]

plt.plot(x_vals, ra_avr, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
plt.plot(x_vals, d3pg_avr, linestyle="-", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
plt.plot(x_vals, madrl_avr, linestyle="-", marker=markers[2], markersize=markersize, color=colors[3], label=labels[2], linewidth=5.0)
plt.plot(x_vals, mamodrl_avr, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

plt.grid()
ax = plt.gca()

# plt.ylim(2, 4)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
ax.xaxis.set_major_locator(MultipleLocator(1))

# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# plt.show()
#################################################################### #################################################################
plt.subplot(2, 3, 6)                       # 将画布分为两列
# plt.figure(figsize=(16, 12))
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Average Sensing and Transmission Cost', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[5], fontsize=font_size, y=-0.2)     # 图的title

ra_avsc = [0.3583821610842962, 0.414286938032301, 0.4666399544866637, 0.47825689004884675, 0.479987593334056]
d3pg_avsc = [0.2030783136538018, 0.24684418177343342, 0.23816952224093066, 0.3072714706208964, 0.33898469948479]
madrl_avsc = [0.4243380783217813, 0.5208922848694053, 0.4924105378391942, 0.383844539036185, 0.5056128348603285]
mamodrl_avsc = [0.06750298553201539, 0.1009851778694089, 0.131038247391626, 0.14231871163027582, 0.1589526605773863]

ra_avtc = [0.22371150219058017, 0.261536464874979, 0.2725189588279612, 0.3215836986724971, 0.342474389134135]
d3pg_avtc = [0.063086022030166, 0.08370025880234518, 0.10092650002775551, 0.10447675337869548, 0.11849340024669608]
madrl_avtc = [0.1490982780930486, 0.2132299491823035, 0.186418438623166, 0.2690809793991938, 0.2429359910517098]
mamodrl_avtc = [0.031592382440125376, 0.0236390380707191, 0.03968007878976352, 0.07055067328456877, 0.0749898983945935]

# plt.plot(x_vals, ra_avsc, linestyle="-", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0)
# plt.plot(x_vals, d3pg_avsc, linestyle="-", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0)
# plt.plot(x_vals, madrl_avsc, linestyle="-", marker=markers[2], markersize=markersize, color=colors[3], label=labels[2], linewidth=5.0)
# plt.plot(x_vals, mamodrl_avsc, linestyle="-", marker=markers[4], markersize=markersize, color=colors[4], label=labels[3], linewidth=5.0)

# plt.plot(x_vals, ra_avtc, linestyle="-.", marker=markers[0], markersize=markersize, color=colors[0], linewidth=5.0)
# plt.plot(x_vals, d3pg_avtc, linestyle="-.", marker=markers[1], markersize=markersize, color=colors[2], linewidth=5.0)
# plt.plot(x_vals, madrl_avtc, linestyle="-.", marker=markers[2], markersize=markersize, color=colors[3], linewidth=5.0)
# plt.plot(x_vals, mamodrl_avtc, linestyle="-.", marker=markers[4], markersize=markersize, color=colors[4], linewidth=5.0)


diff = 1
x = np.arange(1, 6, 1)

width = diff * 0.12
small_width = diff * 0.03
label_text_size = 35

plt.bar(x - width - 5 * small_width, ra_avtc, width, label='ATC', hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x - width - 5 * small_width, ra_avsc, width, label='ASC', bottom=ra_avtc, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] - width - 7.5 * small_width, ra_avtc[i]+ra_avsc[i]+0.03*1, labels[0], fontsize=label_text_size, rotation=90)

plt.bar(x - width + 1 * small_width, d3pg_avtc, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x - width + 1 * small_width, d3pg_avsc, width, bottom=d3pg_avtc, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] - width + -1.5 *  small_width, d3pg_avtc[i]+d3pg_avsc[i]+0.03*1, labels[1], fontsize=label_text_size, rotation=90)

plt.bar(x + 3 * small_width, madrl_avtc, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x + 3 * small_width, madrl_avsc, width, bottom=madrl_avtc, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] + 0.5 * small_width, madrl_avsc[i]+madrl_avtc[i]+0.03*1, labels[2], fontsize=label_text_size, rotation=90)

plt.bar(x + 9 * small_width, mamodrl_avtc, width, hatch="/", color=new_colors[0], edgecolor=None)
plt.bar(x + 9 * small_width, mamodrl_avsc, width, bottom=mamodrl_avtc, hatch="\\", color=new_colors[1], edgecolor=None)

for i in range(len(x_vals)):
    plt.text(x[i] + 6.5 * small_width, mamodrl_avsc[i]+mamodrl_avtc[i]+0.03*1, labels[3], fontsize=label_text_size, rotation=90)

# plt.grid()
ax = plt.gca()
new_x_index = ['3', '4', '5', '6', '7']
plt.xticks(x, new_x_index, fontsize=font_size)

plt.ylim(0, 1)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
# ax = plt.gca()
# ax.xaxis.set_major_locator(MultipleLocator(1))
plt.grid()
# plt.savefig('different_bandwidth.png', dpi=50)
plt.subplots_adjust(wspace =0.2, hspace =0.25)#调整子图间距
plt.savefig("Fig-Different-Numbers.pdf", bbox_inches='tight')
plt.show()
