# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)

# # bandwidth=1 
file_name = "/home/neardws/acme/1682a352-089d-11ed-bbfd-04d9f5632a58/"
# # bandwidth=1.5 
file_name = "/home/neardws/acme/ccc73690-089e-11ed-b941-04d9f5632a58/"
# # bandwidth=2 power=100 information =10
file_name = "/home/neardws/acme/10e98bc6-089e-11ed-9ce8-04d9f5632a58/"
# # bandwidth=2.5 
# file_name = "/home/neardws/acme/349be9ce-089e-11ed-a9cf-04d9f5632a58/"
# # bandwidth=3 
# file_name = "/home/neardws/acme/4e628b56-089e-11ed-a828-04d9f5632a58/"


# # power=50 
# file_name = "/home/neardws/acme/00af5ab8-08a0-11ed-bd82-04d9f5632a58/"
# # power=75 
# file_name = "/home/neardws/acme/21f113e2-08a0-11ed-b8e7-04d9f5632a58/"
# # power=125
# file_name = "/home/neardws/acme/3955d78e-08a0-11ed-99ed-04d9f5632a58/"
# # power=150
# file_name = "/home/neardws/acme/4817ee60-08a0-11ed-9a0b-04d9f5632a58/"

# # information=6
file_name = "/home/neardws/acme/6a560408-08a0-11ed-a5eb-04d9f5632a58/"
# # information=8
file_name = "/home/neardws/acme/7e7f2130-08a0-11ed-ad70-04d9f5632a58/"
# # information=12
file_name = "/home/neardws/acme/8d87a5c6-08a0-11ed-b289-04d9f5632a58/"
# # information=14
file_name = "/home/neardws/acme/9c2b00b4-08a0-11ed-955b-04d9f5632a58/"


# # bandwidth = 2 scenario = 2 
# # 5000

file_name = "/home/neardws/acme/7315294e-0bdd-11ed-9d96-04d9f5632a58/"


returns_file_name = file_name + "logs/environment_loop/logs.csv"

returns_df = pd.read_csv(returns_file_name, names=["average_aovs", "average_consistencys", "average_costs", "average_redundancys", "average_sensing_costs", "average_timelinesss", "average_transmission_costs", "cumulative_aovs", "cumulative_costs", "episode_length", "episode_return", "episodes", "label", "steps", "steps_per_second"], header=0)
episode_return = returns_df["episode_return"].values
cumulative_aovs = returns_df["cumulative_aovs"].values
cumulative_costs = returns_df["cumulative_costs"].values
average_aovs = returns_df["average_aovs"].values
average_costs = returns_df["average_costs"].values
average_timelinesss = returns_df["average_timelinesss"].values
average_consistencys = returns_df["average_consistencys"].values
average_redundancys = returns_df["average_redundancys"].values
average_sensing_costs = returns_df["average_sensing_costs"].values
average_transmission_costs = returns_df["average_transmission_costs"].values

returns_df["cumulative_aovs"].to_csv("random_aov.csv")
returns_df["cumulative_costs"].to_csv("random_cov.csv")
returns = np.zeros(shape=(len(episode_return), 2, 12))

for ret_index in range(episode_return.shape[0]):
    process_str = episode_return[ret_index].replace("[", "").replace("]", "").replace("\n", "").split(" ")
    while "" in process_str:
        process_str.remove("")
    for index in range(len(process_str)):
        s = process_str[index]
        f_s = float(s)
        returns[ret_index][index % 2][int(np.floor(index / 2))] = f_s

epoch_index = [i for i in range(episode_return.shape[0])]


v1_return = returns[:, 0, 0].tolist()
v2_return = returns[:, 0, 1].tolist()
v3_return = returns[:, 0, 2].tolist()
v4_return = returns[:, 0, 3].tolist()
v5_return = returns[:, 0, 4].tolist()
v6_return = returns[:, 0, 5].tolist()
v7_return = returns[:, 0, 6].tolist()
v8_return = returns[:, 0, 7].tolist()
v9_return = returns[:, 0, 8].tolist()
v10_return = returns[:, 0, 9].tolist()
plt.plot(epoch_index, v1_return, '-', color='lightgreen', label='v1_aov')
plt.plot(epoch_index, v2_return, '-', color='deepskyblue', label='v2_aov')
plt.plot(epoch_index, v3_return, '-', color='midnightblue', label='v3_aov')
plt.plot(epoch_index, v4_return, '-', color='pink', label='v4_aov')
plt.plot(epoch_index, v5_return, '-', color='coral', label='v5_aov')
plt.plot(epoch_index, v6_return, '-', color='gray', label='v6_aov')
plt.plot(epoch_index, v7_return, '-', color='darkred', label='v7_aov')
plt.plot(epoch_index, v8_return, '-', color='orange', label='v8_aov')
plt.plot(epoch_index, v9_return, '-', color='blueviolet', label='v9_aov')
plt.plot(epoch_index, v10_return, '-', color='black', label='v10_aov')
plt.legend(loc="best")  # 图例
plt.show()

edge_return = returns[:, 0, 10].tolist()
plt.plot(epoch_index, edge_return, '-', color='lightgreen', label='edge_aov')
plt.legend(loc="best")  # 图例
plt.show()

# start_index = 75
# end_index = 100
global_return = returns[:, 0, 11].tolist()
plt.plot(epoch_index, global_return, '-', color='lightgreen', label='global_aov')
plt.legend(loc="best")  # 图例
plt.show()


v1_return = returns[:, 1, 0].tolist()
v2_return = returns[:, 1, 1].tolist()
v3_return = returns[:, 1, 2].tolist()
v4_return = returns[:, 1, 3].tolist()
v5_return = returns[:, 1, 4].tolist()
v6_return = returns[:, 1, 5].tolist()
v7_return = returns[:, 1, 6].tolist()
v8_return = returns[:, 1, 7].tolist()
v9_return = returns[:, 1, 8].tolist()
v10_return = returns[:, 1, 9].tolist()
plt.plot(epoch_index, v1_return, '-', color='lightgreen', label='v1_cost')
plt.plot(epoch_index, v2_return, '-', color='deepskyblue', label='v2_cost')
plt.plot(epoch_index, v3_return, '-', color='midnightblue', label='v3_cost')
plt.plot(epoch_index, v4_return, '-', color='pink', label='v4_cost')
plt.plot(epoch_index, v5_return, '-', color='coral', label='v5_cost')
plt.plot(epoch_index, v6_return, '-', color='gray', label='v6_cost')
plt.plot(epoch_index, v7_return, '-', color='darkred', label='v7_cost')
plt.plot(epoch_index, v8_return, '-', color='orange', label='v8_cost')
plt.plot(epoch_index, v9_return, '-', color='blueviolet', label='v9_cost')
plt.plot(epoch_index, v10_return, '-', color='black', label='v10_cost')
plt.legend(loc="best")  # 图例
plt.show()

edge_return = returns[:, 1, 10].tolist()
plt.plot(epoch_index, edge_return, '-', color='lightgreen', label='edge_cost')
plt.legend(loc="best")  # 图例
plt.show()

global_return = returns[:, 1, 11].tolist()
plt.plot(epoch_index, global_return, '-', color='lightgreen', label='global_cost')
plt.legend(loc="best")  # 图例
plt.show()


plt.plot(epoch_index, cumulative_aovs, '-', color='lightgreen', label='cumulative_aovs')
plt.legend(loc="best")  # 图例
plt.show()

plt.plot(epoch_index, cumulative_costs, '-', color='lightgreen', label='cumulative_costs')
plt.legend(loc="best")  # 图例
plt.show()

plt.plot(epoch_index, average_aovs, '-', color='lightgreen', label='average_aovs')
plt.legend(loc="best")  # 图例
plt.show()

plt.plot(epoch_index, average_costs, '-', color='lightgreen', label='average_costs')
plt.legend(loc="best")  # 图例
plt.show()

plt.plot(epoch_index, average_timelinesss, '-', color='lightgreen', label='average_timelinesss')
plt.legend(loc="best")  # 图例
plt.show()

plt.plot(epoch_index, average_consistencys, '-', color='lightgreen', label='average_consistencys')
plt.legend(loc="best")  # 图例
plt.show()

plt.plot(epoch_index, average_redundancys, '-', color='lightgreen', label='average_redundancys')
plt.legend(loc="best")  # 图例
plt.show()

plt.plot(epoch_index, average_sensing_costs, '-', color='lightgreen', label='average_sensing_costs')
plt.legend(loc="best")  # 图例
plt.show()

plt.plot(epoch_index, average_transmission_costs, '-', color='lightgreen', label='average_transmission_costs')
plt.legend(loc="best")  # 图例
plt.show()

start_index = 25
end_index = 75
print("cumulative_aovs: ", cumulative_aovs[start_index:end_index].mean())
print("cumulative_costs: ", cumulative_costs[start_index:end_index].mean())
print("average_aovs: ", average_aovs[start_index:end_index].mean())
print("average_costs: ", average_costs[start_index:end_index].mean())
print("average_timelinesss: ", average_timelinesss[start_index:end_index].mean())
print("average_consistencys: ", average_consistencys[start_index:end_index].mean())
print("average_redundancys: ", average_redundancys[start_index:end_index].mean())
print("average_sensing_costs: ", average_sensing_costs[start_index:end_index].mean())
print("average_transmission_costs: ", average_transmission_costs[start_index:end_index].mean())

for start_index in range(85, 100):
    print("*" * 32)
    print("cumulative_aovs: ", cumulative_aovs[start_index])
    print("cumulative_costs: ", cumulative_costs[start_index])
    print("average_aovs: ", average_aovs[start_index])
    print("average_costs: ", average_costs[start_index])
    print("average_timelinesss: ", average_timelinesss[start_index])
    print("average_consistencys: ", average_consistencys[start_index])
    print("average_redundancys: ", average_redundancys[start_index])
    print("average_sensing_costs: ", average_sensing_costs[start_index])
    print("average_transmission_costs: ", average_transmission_costs[start_index])
# Out:
# cumulative_aovs:  225.43382947281785
# cumulative_costs:  192.66666782972388
# average_aovs:  0.24855390175727377
# average_costs:  0.35777777390092036
# average_timelinesss:  0.23300475675742874
# average_consistencys:  0.27187761925704124
# average_redundancys:  0.24455714285714286
# average_sensing_costs:  0.4778112946714016
# average_transmission_costs:  0.29435456865232806
# ********************************
# cumulative_aovs:  230.9727064695987
# cumulative_costs:  194.27773943730563
# average_aovs:  0.2300909784346714
# average_costs:  0.3524075352089811
# average_timelinesss:  0.2080189672650845
# average_consistencys:  0.2631989951890521
# average_redundancys:  0.2446428571428569
# average_sensing_costs:  0.4741858756670259
# average_transmission_costs:  0.284511533783998
# ********************************
# cumulative_aovs:  225.54920544255395
# cumulative_costs:  193.651591436455
# average_aovs:  0.2481693151914871
# average_costs:  0.3544946952118167
# average_timelinesss:  0.2341351221481973
# average_consistencys:  0.2692206047564216
# average_redundancys:  0.2421428571428572
# average_sensing_costs:  0.4755166249079748
# average_transmission_costs:  0.2896486845501381
# ********************************
# cumulative_aovs:  232.1991079743945
# cumulative_costs:  192.3197653755564
# average_aovs:  0.226002973418685
# average_costs:  0.3589341154148117
# average_timelinesss:  0.1954008684145252
# average_consistencys:  0.2719061309249244
# average_redundancys:  0.2442857142857141
# average_sensing_costs:  0.4815734340916777
# average_transmission_costs:  0.2936189973024941
# ********************************
# cumulative_aovs:  215.41051831992488
# cumulative_costs:  193.74712508407512
# average_aovs:  0.2819649389335841
# average_costs:  0.3541762497197498
# average_timelinesss:  0.2761198956177346
# average_consistencys:  0.2907325039073585
# average_redundancys:  0.2388095238095239
# average_sensing_costs:  0.4720485755374118
# average_transmission_costs:  0.2939872868571995
# ********************************
# cumulative_aovs:  232.59256308411955
# cumulative_costs:  191.95891919520463
# average_aovs:  0.2246914563862687
# average_costs:  0.360136936015984
# average_timelinesss:  0.210025235073694
# average_consistencys:  0.2466907883551305
# average_redundancys:  0.2485714285714286
# average_sensing_costs:  0.4867401963048569
# average_transmission_costs:  0.2893164294493889
# ********************************
# cumulative_aovs:  231.97934753391053
# cumulative_costs:  195.5798507424818
# average_aovs:  0.2267355082202984
# average_costs:  0.3480671641917275
# average_timelinesss:  0.1945551353137922
# average_consistencys:  0.2750060675800581
# average_redundancys:  0.2417857142857142
# average_sensing_costs:  0.4669891587230673
# average_transmission_costs:  0.2822858946133934
# ********************************
# cumulative_aovs:  228.4369835475844
# cumulative_costs:  191.849763572044
# average_aovs:  0.2385433881747191
# average_costs:  0.3605007880931873
# average_timelinesss:  0.2253646680459989
# average_consistencys:  0.2583114683677992
# average_redundancys:  0.2472619047619048
# average_sensing_costs:  0.4797833712409013
# average_transmission_costs:  0.2978376466111141
# ********************************
# cumulative_aovs:  232.9156822101522
# cumulative_costs:  191.38995949263105
# average_aovs:  0.2236143926328257
# average_costs:  0.3620334683578962
# average_timelinesss:  0.1989248673703338
# average_consistencys:  0.2606486805265636
# average_redundancys:  0.2497619047619047
# average_sensing_costs:  0.4873939683480366
# average_transmission_costs:  0.2928087501657526
# ********************************
# cumulative_aovs:  224.56977494150115
# cumulative_costs:  192.2280330370376
# average_aovs:  0.2514340835283293
# average_costs:  0.3592398898765413
# average_timelinesss:  0.2312679584728328
# average_consistencys:  0.2816832711115739
# average_redundancys:  0.2554761904761905
# average_sensing_costs:  0.476880652561731
# average_transmission_costs:  0.2934809768915273
# ********************************
# cumulative_aovs:  217.3105293418144
# cumulative_costs:  195.47624099839504
# average_aovs:  0.2756315688606192
# average_costs:  0.3484125300053502
# average_timelinesss:  0.2707639491608404
# average_consistencys:  0.282932998410287
# average_redundancys:  0.2304761904761904
# average_sensing_costs:  0.464790498006824
# average_transmission_costs:  0.2910027317684563
# ********************************
# cumulative_aovs:  229.0526428553509
# cumulative_costs:  193.3056969062677
# average_aovs:  0.2364911904821639
# average_costs:  0.355647676979108
# average_timelinesss:  0.2153666404918152
# average_consistencys:  0.2681780154676871
# average_redundancys:  0.2461904761904761
# average_sensing_costs:  0.4733189348092375
# average_transmission_costs:  0.2927050195432945
# ********************************
# cumulative_aovs:  229.36318056049788
# cumulative_costs:  195.5317369379393
# average_aovs:  0.2354560647983402
# average_costs:  0.3482275435402023
# average_timelinesss:  0.2192332639837959
# average_consistencys:  0.2597902660201571
# average_redundancys:  0.2332142857142859
# average_sensing_costs:  0.4678958047371151
# average_transmission_costs:  0.2860659112562476
# ********************************
# cumulative_aovs:  228.405959443806
# cumulative_costs:  192.778042919908
# average_aovs:  0.2386468018539801
# average_costs:  0.3574065236003072
# average_timelinesss:  0.2159380904406811
# average_consistencys:  0.2727098689739279
# average_redundancys:  0.2453571428571427
# average_sensing_costs:  0.4804974477721869
# average_transmission_costs:  0.2903402898000099
# ********************************
# cumulative_aovs:  219.66863243376065
# cumulative_costs:  195.07001833664611
# average_aovs:  0.2677712252207977
# average_costs:  0.349766605544512
# average_timelinesss:  0.2638714130076241
# average_consistencys:  0.2736209435405586
# average_redundancys:  0.2365555555555556
# average_sensing_costs:  0.468397329913634
# average_transmission_costs:  0.2877414061698687
# ********************************
# cumulative_aovs:  226.23866496775847
# cumulative_costs:  194.71607162933185
# average_aovs:  0.2458711167741388
# average_costs:  0.3509464279022277
# average_timelinesss:  0.2329958158792937
# average_consistencys:  0.265184068116407
# average_redundancys:  0.2287777777777782
# average_sensing_costs:  0.4696846178272877
# average_transmission_costs:  0.2932925630393924
